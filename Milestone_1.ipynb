# %% [markdown]
# <a href="https://colab.research.google.com/github/SodadasiSushanthi/INFOSYS-VIRTUAL-INTERNSHIP-6.0/blob/main/Milestone_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------
# Step 1: Install required library
# -----------------------------
# !pip install --quiet google-api-python-client
print("Library installed successfully!")

# -----------------------------
# Step 2: Import libraries
# -----------------------------
from googleapiclient.discovery import build
import pandas as pd

# -----------------------------
# Step 3: Set API key and Channel ID
# -----------------------------
api_key = "AIzaSyD2mTSj7if6dJpoUwaXfHh5O9dmw3IE3fo"          # Replace with your YouTube Data API key
channel_id = "UC4rlAVgAK0SGk-yTfe48Qpw"  # Replace with the channel ID
max_results = 10                 # Number of latest videos to fetch

# -----------------------------
# Step 4: Build YouTube service
# -----------------------------
youtube = build('youtube', 'v3', developerKey=api_key)

# -----------------------------
# Step 5: Fetch latest videos from the channel
# -----------------------------
search_request = youtube.search().list(
    part='snippet',
    channelId=channel_id,
    maxResults=max_results,
    order='date'
)
search_response = search_request.execute()

# -----------------------------
# Step 6: Extract video IDs
# -----------------------------
video_ids = [item['id']['videoId'] for item in search_response['items'] if item['id']['kind'] == 'youtube#video']

# -----------------------------
# Step 7: Fetch video details
# -----------------------------
video_request = youtube.videos().list(
    part='snippet,contentDetails,statistics',
    id=','.join(video_ids)
)
video_response = video_request.execute()

# -----------------------------
# Step 8: Prepare data for CSV
# -----------------------------
data = []
for video in video_response['items']:
    data.append({
        "Video ID": video['id'],
        "Title": video['snippet']['title'],
        "Description": video['snippet']['description'],
        "Published At": video['snippet']['publishedAt'],
        "Duration": video['contentDetails']['duration'],
        "Views": video['statistics'].get('viewCount', 'N/A')
    })

df = pd.DataFrame(data)

# -----------------------------
# Step 9: Save data to CSV
# -----------------------------
csv_file = "youtube_videos.csv"
df.to_csv(csv_file, index=False)
print(f"Video details saved to {csv_file}")

# -----------------------------
# Step 10: Display the data
# -----------------------------
df
# Out:
# Library installed successfully!
# Video details saved to youtube_videos.csv
#       Video ID                                              Title  \
# 0  znfKpNQ4huY  NASA Confirmed the Most Dangerous Asteroid Is ...
# 1  fnzLXN9J5zo  Animals That Prove Nature Was Definitely Glitc...
# 2  SUFY8sBnSpQ  15 Optical Illusions That Will Trick Your Brai...
# 3  h5CznvUrU1I  Astronomers Finally Explain the Strangest Obje...
# 4  PlO1c14IwvA  Earth Is Hiding More Continents Than We Ever Knew
# 5  DZupG496jK0  If You See These Things Under the Ice, Don't G...
# 6  GBMZDyQR0Tc  7 Finds in Antarctica That Rocked the Scientif...
# 7  vSQaSBXYk_0  Sunken Ship Found in the Middle of a Cornfield...
# 8  wwFgXrW8yqs  New Discovery Finally Reveals How the Pyramids...
# 9  HJ7W1npdGmE   Scientists Finally Know How Stonehenge Was Built
#
#                                          Description          Published At  \
# 0  A massive asteroid named Apophis could come da...  2025-10-16T00:14:29Z
# ...

# %%
# Step 1: Install the Google API client
# !pip install --quiet google-api-python-client pandas

# Step 2: Import required libraries
from googleapiclient.discovery import build
import pandas as pd

# Step 3: Set up your YouTube API credentials
API_KEY = 'AIzaSyD2mTSj7if6dJpoUwaXfHh5O9dmw3IE3fo'  # <-- Replace with your actual API key
CHANNEL_ID = 'UC4rlAVgAK0SGk-yTfe48Qpw'  # <-- Replace with the target channel ID

youtube = build('youtube', 'v3', developerKey=API_KEY)

# Step 4: Function to fetch all videos using pagination
def get_all_videos(channel_id):
    videos = []
    next_page_token = None

    while True:
        # Fetch playlist ID for uploaded videos
        res = youtube.channels().list(
            part='contentDetails',
            id=channel_id
        ).execute()

        uploads_playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']

        # Fetch videos from playlist
        playlist_res = youtube.playlistItems().list(
            part='snippet',
            playlistId=uploads_playlist_id,
            maxResults=50,  # maximum allowed by API
            pageToken=next_page_token
        ).execute()

        for item in playlist_res['items']:
            video_id = item['snippet']['resourceId']['videoId']
            title = item['snippet']['title']
            published_at = item['snippet']['publishedAt']
            videos.append({
                'video_id': video_id,
                'title': title,
                'published_at': published_at
            })

        next_page_token = playlist_res.get('nextPageToken')
        if not next_page_token:
            break

    return videos

# Step 5: Run function and save to CSV
video_list = get_all_videos(CHANNEL_ID)
df = pd.DataFrame(video_list)
df.to_csv('youtube_channel_videos.csv', index=False)

print(f"✅ {len(video_list)} videos fetched and saved to 'youtube_channel_videos.csv'.")
# Out:
# ✅ 10557 videos fetched and saved to 'youtube_channel_videos.csv'.

# %%
df.head()  # shows the first 5 videos
print(f"Total videos fetched: {len(df)}")
# Out:
# Total videos fetched: 10557

# %%
# Save CSV
df.to_csv('youtube_channel_videos.csv', index=False)

# Download
from google.colab import files
files.download('youtube_channel_videos.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')  # This will ask for permission

# Save CSV to Drive
df.to_csv('/content/drive/MyDrive/youtube_channel_videos.csv', index=False)
print("CSV saved to Google Drive successfully!")
# Out:
# Mounted at /content/drive
# CSV saved to Google Drive successfully!

# %%
from google.colab import files
files.download('/content/drive/MyDrive/youtube_channel_videos.csv')

# %%
# youtube_fetch_extended.py
import os
import csv
import pandas as pd
from googleapiclient.discovery import build

API_KEY = os.environ.get("UC_pY1kHkancfQ8a-Ais9qIw", "AIzaSyD2mTSj7if6dJpoUwaXfHh5O9dmw3IE3fo")  # set env var in Colab/local
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey=API_KEY)

def search_videos(query, max_results=10):
    # search.list -> gives videoIds (cost: search.list = 100 units per call)
    res = youtube.search().list(
        q=query,
        part="id",         # we only need the IDs from search
        type="video",
        maxResults=max_results
    ).execute()
    video_ids = [item['id']['videoId'] for item in res.get('items', [])]
    return video_ids

def fetch_videos(video_id_list):
    # videos.list -> get snippet, contentDetails, statistics, status (cost: typically 1 unit)
    if not video_id_list:
        return []
    res = youtube.videos().list(
        part="snippet,contentDetails,statistics,status",
        id=",".join(video_id_list),
        maxResults=50
    ).execute()
    videos = []
    for item in res.get("items", []):
        vid = {
            "id": item.get("id"),
            "title": item.get("snippet", {}).get("title"),
            "description": item.get("snippet", {}).get("description"),
            "publishedAt": item.get("snippet", {}).get("publishedAt"),
            "tags": item.get("snippet", {}).get("tags"),
            "categoryId": item.get("snippet", {}).get("categoryId"),
            "defaultLanguage": item.get("snippet", {}).get("defaultLanguage"),
            "defaultAudioLanguage": item.get("snippet", {}).get("defaultAudioLanguage"),
            "thumbnails": item.get("snippet", {}).get("thumbnails"),
            "duration": item.get("contentDetails", {}).get("duration"),
            "viewCount": item.get("statistics", {}).get("viewCount"),
            "likeCount": item.get("statistics", {}).get("likeCount"),
            "commentCount": item.get("statistics", {}).get("commentCount"),
            "privacyStatus": item.get("status", {}).get("privacyStatus")
        }
        videos.append(vid)
    return videos

def fetch_channel(channel_id):
    res = youtube.channels().list(
        part="snippet,statistics",
        id=channel_id
    ).execute()
    items = res.get("items", [])
    if not items:
        return None
    c = items[0]
    chan = {
        "id": c.get("id"),
        "title": c.get("snippet", {}).get("title"),
        "description": c.get("snippet", {}).get("description"),
        "thumbnail": c.get("snippet", {}).get("thumbnails"),
        "subscriberCount": c.get("statistics", {}).get("subscriberCount"),
        "videoCount": c.get("statistics", {}).get("videoCount")
    }
    return chan

if __name__ == "__main__":
    # Example usage:
    query = "machine learning tutorials"
    video_ids = search_videos(query, max_results=10)
    print("Found video IDs:", video_ids)

    videos = fetch_videos(video_ids)
    df = pd.DataFrame(videos)
    df.to_csv("youtube_videos_full.csv", index=False)
    print("Saved", len(df), "video records to youtube_videos_full.csv")

    # Count video units (rows)
    print("Total Video Units in CSV:", len(df))
# Out:
# Found video IDs: ['ukzFI9rgwfU', 'PeMlggyqz0Y', 'i_LwzRVP7bg', '7eh4d6sabA0', 'Pj0neYUp9Tc', 'qYNweeDHiyU', 'E0Hmnixke2g', 'gmvvaobm7eQ', 'QBw7bFZ7OT8', 'GwIo3gDZCVQ']
# Saved 10 video records to youtube_videos_full.csv
# Total Video Units in CSV: 10

# %%
# --- Step 1 : Mount Google Drive ---
from google.colab import drive
drive.mount('/content/drive')

# --- Step 2 : Import pandas ---
import pandas as pd

# --- Step 3 : Read your CSV from Google Drive ---
# 🔹 Replace the path below with your exact file location if it differs
csv_path = '/content/drive/MyDrive/youtube_channel_videos.csv'

# --- Step 4 : Load the CSV and count rows ---
df = pd.read_csv(csv_path)

# --- Step 5 : Print total number of video units ---
print("Total Video Units:", len(df))
# Out:
# Mounted at /content/drive
# Total Video Units: 10557

# %%
# !pip install --upgrade google-api-python-client pandas python-dateutil
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 65.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.184.0
#     Uninstalling google-api-python-client-2.184.0:
#       Successfully uninstalled google-api-python-client-2.184.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
# --------------------------
# YouTube full details fetch
# Paste into Google Colab (one cell) and run
# Replace api_key and channel_id below
# --------------------------

from googleapiclient.discovery import build
from dateutil import parser as dateparser
import pandas as pd
import re
import math
import time

# ---------- CONFIG ----------
api_key = "AIzaSyD2mTSj7if6dJpoUwaXfHh5O9dmw3IE3fo"        # <<---- put your API key here
channel_id = "UC4rlAVgAK0SGk-yTfe48Qpw"  # <<---- put the channel id here
max_results_per_search = 50   # 50 is max allowed per search.list
# ----------------------------

youtube = build('youtube', 'v3', developerKey=api_key)

def iso8601_duration_to_hms(iso_duration: str) -> str:
    # converts ISO 8601 like PT1H2M3S to HH:MM:SS
    if not iso_duration:
        return ""
    hours = minutes = seconds = 0
    m = re.match(r'^PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?$', iso_duration)
    if not m:
        return iso_duration
    if m.group(1): hours = int(m.group(1))
    if m.group(2): minutes = int(m.group(2))
    if m.group(3): seconds = int(m.group(3))
    total = hours*3600 + minutes*60 + seconds
    return f"{total//3600:02d}:{(total%3600)//60:02d}:{total%60:02d}"

# ---------- 1) Get Channel details ----------
chan_req = youtube.channels().list(part="snippet,statistics", id=channel_id)
chan_res = chan_req.execute()

if not chan_res.get('items'):
    raise SystemExit("Channel not found. Check the channel_id value.")

chan = chan_res['items'][0]
channel_info = {
    "id": chan.get('id'),
    "title": chan['snippet'].get('title'),
    "description": chan['snippet'].get('description'),
    "country": chan['snippet'].get('country', "Not Available"),
    "thumbnail": chan['snippet']['thumbnails']['default']['url'] if 'thumbnails' in chan['snippet'] else None,
    "subscriberCount": chan['statistics'].get('subscriberCount', "Hidden or N/A"),
    "videoCount": chan['statistics'].get('videoCount', 0)
}

print("=== Channel Info ===")
for k,v in channel_info.items():
    print(f"{k}: {v}")
print("====================\n")

# ---------- 2) Use search.list to gather ALL video IDs via pagination ----------
video_ids = []
nextToken = None
while True:
    req = youtube.search().list(
        part="id,snippet",
        channelId=channel_id,
        maxResults=max_results_per_search,
        order="date",
        type="video",
        pageToken=nextToken
    )
    res = req.execute()
    for item in res.get('items', []):
        # ensure it's a video and has videoId
        vid = item['id'].get('videoId')
        if vid:
            video_ids.append(vid)
    nextToken = res.get('nextPageToken')
    if not nextToken:
        break
    # short sleep to be polite
    time.sleep(0.1)

print(f"Total videos found: {len(video_ids)}")

# ---------- 3) Batch video_ids into chunks for videos.list (max 50 per call) ----------
def chunk_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

rows = []
for chunk in chunk_list(video_ids, 50):
    vid_str = ",".join(chunk)
    vreq = youtube.videos().list(part="snippet,contentDetails,statistics,status", id=vid_str, maxResults=50)
    vres = vreq.execute()
    for v in vres.get('items', []):
        snip = v.get('snippet', {})
        cont = v.get('contentDetails', {})
        stats = v.get('statistics', {})
        status = v.get('status', {})

        row = {
            "id": v.get('id'),
            "title": snip.get('title'),
            "description": snip.get('description'),
            "publishedAt": snip.get('publishedAt'),
            "tags": snip.get('tags', []),
            "categoryId": snip.get('categoryId'),
            "defaultLanguage": snip.get('defaultLanguage', None),
            "defaultAudioLanguage": snip.get('defaultAudioLanguage', None),
            "thumbnails": snip.get('thumbnails', {}),
            "duration_iso8601": cont.get('duration'),
            "duration_hms": iso8601_duration_to_hms(cont.get('duration')),
            "viewCount": int(stats.get('viewCount', 0)),
            "likeCount": int(stats.get('likeCount', 0)) if stats.get('likeCount') is not None else None,
            "commentCount": int(stats.get('commentCount', 0)) if stats.get('commentCount') is not None else None,
            "privacyStatus": status.get('privacyStatus', None)
        }
        rows.append(row)
    # short sleep
    time.sleep(0.1)

# ---------- 4) Save results to CSV ----------
df = pd.DataFrame(rows)
# Expand thumbnail default URL for simpler CSV column
df['thumbnail_default_url'] = df['thumbnails'].apply(lambda t: t.get('default', {}).get('url') if isinstance(t, dict) else None)

# Save channel info + videos CSV
df.to_csv("youtube_videos.csv", index=False)
print("Saved video details to youtube_videos.csv")

# Also print top 5 rows as quick check
print("\nSample rows:")
display(df.head())
# Out:
# === Channel Info ===
# id: UC4rlAVgAK0SGk-yTfe48Qpw
# title: BRIGHT SIDE
# description: Whether you’re into recent discoveries, space exploration, true stories, fitness, fun tests, and riddles, or useful tips for self-improvement, psychology, gadgets, or just your day-to-day routine, there’s something for everyone!
#
# You can expect all that and more coming at you in 3 top-quality videos every single day. If you’ve got a thirst for knowledge that never quits, then join a community of tens of millions and growing! We have a good time, so take your shoes off, kick back, and make yourself at home here on the Bright Side of life!
#
# Good news! We launched a new app for you 👉 http://bit.ly/Bs3App7
# Join the world's largest community of good people! 😉
#
# For brand partnership enquires: brands@thesoul-publishing.com
# country: Not Available
# thumbnail: https://yt3.ggpht.com/BimIuq2UYH1h-GQDEiV89I1dUEtpWVR8Mp_Q516vPN8rLw488Ap1G9ALhPUyqN8_HTPMbawTBDk=s88-c-k-c0x00ffffff-no-rj
# ...

# %%
# --------------------------
# YouTube full details fetch (Shows 50 sample rows)
# Paste into Google Colab (one cell)
# --------------------------

from googleapiclient.discovery import build
from dateutil import parser as dateparser
import pandas as pd
import re
import time

# ---------- CONFIG ----------
api_key = "AIzaSyD2mTSj7if6dJpoUwaXfHh5O9dmw3IE3fo"       # <<--- replace with your API key
channel_id = "UC4rlAVgAK0SGk-yTfe48Qpw"                   # <<--- replace with your channel ID
max_results_per_search = 50
# ----------------------------

youtube = build('youtube', 'v3', developerKey=api_key)

# Convert ISO 8601 duration (PT1H2M3S) → HH:MM:SS
def iso8601_duration_to_hms(iso_duration: str) -> str:
    if not iso_duration:
        return ""
    import re
    h = m = s = 0
    match = re.match(r"PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?", iso_duration)
    if match:
        h = int(match.group(1)) if match.group(1) else 0
        m = int(match.group(2)) if match.group(2) else 0
        s = int(match.group(3)) if match.group(3) else 0
    return f"{h:02d}:{m:02d}:{s:02d}"

# ---------- 1) Get Channel details ----------
chan_req = youtube.channels().list(part="snippet,statistics", id=channel_id)
chan_res = chan_req.execute()

if not chan_res.get('items'):
    raise SystemExit("❌ Channel not found. Check the channel_id value.")

chan = chan_res['items'][0]
channel_info = {
    "id": chan['id'],
    "title": chan['snippet']['title'],
    "description": chan['snippet'].get('description', ''),
    "country": chan['snippet'].get('country', "Not Available"),
    "thumbnail": chan['snippet']['thumbnails']['default']['url'],
    "subscriberCount": chan['statistics'].get('subscriberCount', "Hidden"),
    "videoCount": chan['statistics'].get('videoCount', 0)
}

print("=== Channel Info ===")
for k, v in channel_info.items():
    print(f"{k}: {v}")
print("====================\n")

# ---------- 2) Collect ALL video IDs ----------
video_ids = []
nextPageToken = None

while True:
    req = youtube.search().list(
        part="id",
        channelId=channel_id,
        maxResults=max_results_per_search,
        order="date",
        type="video",
        pageToken=nextPageToken
    )
    res = req.execute()
    for item in res.get('items', []):
        vid = item['id'].get('videoId')
        if vid:
            video_ids.append(vid)
    nextPageToken = res.get('nextPageToken')
    if not nextPageToken:
        break
    time.sleep(0.1)

print(f"✅ Total videos found: {len(video_ids)}")

# ---------- 3) Fetch details for each video ----------
def chunk_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

rows = []
for chunk in chunk_list(video_ids, 50):
    req = youtube.videos().list(
        part="snippet,contentDetails,statistics,status",
        id=",".join(chunk),
        maxResults=50
    )
    res = req.execute()

    for v in res.get('items', []):
        snip = v.get('snippet', {})
        cont = v.get('contentDetails', {})
        stats = v.get('statistics', {})
        status = v.get('status', {})

        rows.append({
            "id": v.get('id'),
            "title": snip.get('title'),
            "description": snip.get('description'),
            "publishedAt": snip.get('publishedAt'),
            "tags": snip.get('tags', []),
            "categoryId": snip.get('categoryId'),
            "defaultLanguage": snip.get('defaultLanguage'),
            "defaultAudioLanguage": snip.get('defaultAudioLanguage'),
            "thumbnails": snip.get('thumbnails'),
            "thumbnail_default_url": snip.get('thumbnails', {}).get('default', {}).get('url'),
            "duration_iso8601": cont.get('duration'),
            "duration_hms": iso8601_duration_to_hms(cont.get('duration')),
            "viewCount": stats.get('viewCount'),
            "likeCount": stats.get('likeCount'),
            "commentCount": stats.get('commentCount'),
            "privacyStatus": status.get('privacyStatus')
        })
    time.sleep(0.1)

# ---------- 4) Save & Display ----------
df = pd.DataFrame(rows)
df.to_csv("youtube_videos.csv", index=False)
print("💾 Saved all video details to youtube_videos.csv\n")

# Display 50 sample rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
print("=== Showing first 50 rows ===")
display(df.head(50))
# Out:
# === Channel Info ===
# id: UC4rlAVgAK0SGk-yTfe48Qpw
# title: BRIGHT SIDE
# description: Whether you’re into recent discoveries, space exploration, true stories, fitness, fun tests, and riddles, or useful tips for self-improvement, psychology, gadgets, or just your day-to-day routine, there’s something for everyone!
#
# You can expect all that and more coming at you in 3 top-quality videos every single day. If you’ve got a thirst for knowledge that never quits, then join a community of tens of millions and growing! We have a good time, so take your shoes off, kick back, and make yourself at home here on the Bright Side of life!
#
# Good news! We launched a new app for you 👉 http://bit.ly/Bs3App7
# Join the world's largest community of good people! 😉
#
# For brand partnership enquires: brands@thesoul-publishing.com
# country: Not Available
# thumbnail: https://yt3.ggpht.com/BimIuq2UYH1h-GQDEiV89I1dUEtpWVR8Mp_Q516vPN8rLw488Ap1G9ALhPUyqN8_HTPMbawTBDk=s88-c-k-c0x00ffffff-no-rj
# ...

# %%
from googleapiclient.discovery import build
import pandas as pd
import re
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Initialize YouTube API
youtube = build("youtube", "v3", developerKey=API_KEY)

# Convert ISO8601 duration to HH:MM:SS safely
def iso8601_duration_to_hms(iso_duration):
    if not iso_duration:
        return ""
    match = re.match(r"PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?", iso_duration)
    if not match:
        return ""
    h = int(match.group(1)) if match.group(1) else 0
    m = int(match.group(2)) if match.group(2) else 0
    s = int(match.group(3)) if match.group(3) else 0
    return f"{h:02d}:{m:02d}:{s:02d}"

# Get uploads playlist ID for the channel
channel_response = youtube.channels().list(
    part="contentDetails,snippet,statistics",
    id=CHANNEL_ID
).execute()

playlist_id = channel_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
channel_title = channel_response["items"][0]["snippet"]["title"]
print(f"📺 Channel: {channel_title}")

# Fetch at least 50 video IDs (loop through pages)
video_ids = []
next_page_token = None
while len(video_ids) < 50:
    playlist_response = youtube.playlistItems().list(
        part="contentDetails",
        playlistId=playlist_id,
        maxResults=50,
        pageToken=next_page_token
    ).execute()

    video_ids += [item["contentDetails"]["videoId"] for item in playlist_response["items"]]
    next_page_token = playlist_response.get("nextPageToken")
    if not next_page_token:
        break

video_ids = video_ids[:50]  # ensure exactly 50
print(f"✅ Total Video IDs Fetched: {len(video_ids)}")

# Fetch video details for these IDs
videos_data = []
for i in range(0, len(video_ids), 50):
    video_response = youtube.videos().list(
        part="snippet,contentDetails,statistics,status",
        id=",".join(video_ids[i:i+50])
    ).execute()

    for item in video_response.get("items", []):
        snip = item["snippet"]
        cont = item.get("contentDetails", {})
        stats = item.get("statistics", {})
        status = item.get("status", {})

        videos_data.append({
            "id": item["id"],
            "title": snip.get("title"),
            "description": snip.get("description"),
            "publishedAt": snip.get("publishedAt"),
            "tags": snip.get("tags"),
            "categoryId": snip.get("categoryId"),
            "defaultLanguage": snip.get("defaultLanguage"),
            "defaultAudioLanguage": snip.get("defaultAudioLanguage"),
            "thumbnail": snip.get("thumbnails", {}).get("high", {}).get("url"),
            "duration": iso8601_duration_to_hms(cont.get("duration")),
            "viewCount": stats.get("viewCount"),
            "likeCount": stats.get("likeCount"),
            "commentCount": stats.get("commentCount"),
            "privacyStatus": status.get("privacyStatus")
        })

# Convert to DataFrame and save
df = pd.DataFrame(videos_data)
csv_path = "/content/drive/MyDrive/bright_side_50_videos.csv"
df.to_csv(csv_path, index=False)

print(f"📁 CSV File Saved Successfully: {csv_path}")
print(f"✅ Total Videos Fetched and Saved: {len(df)}")
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 📺 Channel: BRIGHT SIDE
# ✅ Total Video IDs Fetched: 50
# 📁 CSV File Saved Successfully: /content/drive/MyDrive/bright_side_50_videos.csv
# ✅ Total Videos Fetched and Saved: 50
#             id                                              title  \
# 0  C8VhOyBZvik  Earth Has Invisible Borders That No Desert Can...
# 1  rYVclzUv0SQ  15 Tricky Riddles That Will Make You See What ...
# 2  nAcNzWGTFUc  Ships and Planes Didn’t Vanish Here for the Re...
# 3  131tii9MGNo  Namibia’s Diamond Miners Find Shipwreck With T...
# 4  DQXbmQuHioE  Titanic Could’ve Survived But One Decision Cha...
#
#                                          description           publishedAt  \
# 0  Earth has invisible lines that no desert can c...  2025-10-20T12:02:41Z
# 1  Think you notice everything? Put your eyes (an...  2025-10-21T00:01:05Z
# ...
